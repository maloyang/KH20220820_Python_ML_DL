# %% [markdown]
# # MatPlotLib
#
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python
#
# - ref: https://matplotlib.org/
# - ref: http://www.aosabook.org/en/matplotlib.html
#     - https://matplotlib.org/stable/users/getting_started/

# %% [markdown]
# ## 我們假設你是使用 Anaconda，所以已經內建matplotlib
# - 如果沒有的話，可以使用指令安裝 `pip install matplotlib`
# ----

# %% [markdown]
# ### 第一個demo

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

data = [1, 2, 3, 4, 3, 2, 1]
plt.plot(data)
plt.show()

# %% [markdown]
# ### Style

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# - OO-style

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
x = [1, 2, 3, 4]
y = [1, 4, 2, 3]
ax.plot(x, y);  # Plot some data on the axes.

# %% [markdown]
# - pyplot-style

# %%
x = [1, 2, 3, 4]
y = [1, 4, 2, 3]
plt.plot(x, y)

# %% [markdown]
# - figure的各部分說明
#
# ![img](img/anatomy.png)

# %% [markdown]
# ### 一維

# %%
x = np.arange(10)
plt.plot(x)

# %% [markdown]
# 如果是寫成獨立的程式 (.py 檔)，則需用下面程式來顯示圖形。
#
# ```
# plt.show()
# ```

# %% [markdown]
# ### 二維

# %%
x = np.random.rand(10, 2)
plt.plot(x)
# Out:
# [<matplotlib.lines.Line2D at 0x26327b913d0>,
#  <matplotlib.lines.Line2D at 0x26327b91400>]

# %%
x
# Out:
# array([[0.14345077, 0.71697906],
#        [0.98212795, 0.20974094],
#        [0.36010185, 0.11354385],
#        [0.2119801 , 0.9781152 ],
#        [0.72425817, 0.3959202 ],
#        [0.2600556 , 0.95985734],
#        [0.01905748, 0.55918179],
#        [0.35502167, 0.8493244 ],
#        [0.25762248, 0.76917781],
#        [0.27620708, 0.15103431]])

# %%
# 不是用numpy元件

x1 = [1, 3, 2, 5, 4]
x2 = [8, 7, 6, 5, 5]
plt.plot(x1)
plt.plot(x2)

# %% [markdown]
# ## 子圖 (Subplot)
#
# 參考資料：[Subplot Demo](http://matplotlib.org/examples/pylab_examples/subplots_demo.html)

# %%
plt.subplot(211)
x = np.arange(10)
plt.plot(x)
plt.subplot(212)
y = np.random.rand(10)
plt.plot(y)

# %%
plt.subplot(121)
x = np.arange(10)
plt.plot(x)
plt.subplot(122)
y = np.random.rand(10)
plt.plot(y)

# %%
plt.subplot(221)
x1 = np.random.rand(10)
plt.plot(x1, 'ro')
plt.subplot(222)
x2 = np.random.rand(10)
plt.plot(x2, 'b^')
plt.subplot(223)
x3 = np.random.rand(10)
plt.plot(x3, 'gx')
plt.subplot(224)
x4 = np.random.rand(10)
plt.plot(x4, 'k*')

# %% [markdown]
# ## 畫其他的圖表 (散布圖、餅圖、直方圖等)

# %%
# 請參考：http://matplotlib.org/examples/shapes_and_collections/scatter_demo.html
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)

# %%
# 請參考：http://matplotlib.org/examples/pie_and_polar_charts/pie_demo_features.html
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
# Out:
# (-1.2142507666786346,
#  1.134711077927507,
#  -1.1258468317413044,
#  1.101230806657754)

# %%
# bar chart - 1
N = 10
y = np.random.randint(1, 10, size=N)
x = range(N)
width = 0.5
plt.bar(x, y, width, color="blue")
# Out:
# <BarContainer object of 10 artists>

# %%
# bar chart - 2
N = 10
y = np.random.randint(1, 10, size=N)
x = np.arange(N)
width = 0.5
plt.bar(x - 0.25, y, width, color="blue")
plt.xlim(-1, 10)
# Out:
# (-1, 10)

# %%
y
# Out:
# array([4, 1, 6, 1, 2, 2, 4, 2, 4, 7])

# %%
# histogram
x = np.random.randn(1000)
n_bins = 10

plt.hist(x, n_bins, color='g', rwidth=0.8)
# Out:
# (array([  1.,   2.,  18.,  72., 202., 299., 248., 120.,  32.,   6.]),
#  array([-4.38427188, -3.6078138 , -2.83135571, -2.05489763, -1.27843954,
#         -0.50198146,  0.27447663,  1.05093472,  1.8273928 ,  2.60385089,
#          3.38030897]),
#  <a list of 10 Patch objects>)
