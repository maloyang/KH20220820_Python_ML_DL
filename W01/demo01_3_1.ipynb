# %% [markdown]
# # demo01-3 : 公共腳踏車應用 - 進化版

# %% [markdown]
# ## 新竹市公共自行車租賃系統(YouBike): https://data.gov.tw/dataset/67781

# %%
import requests

# %%
url = "https://odws.hccg.gov.tw/001/Upload/25/OpenData/9059/59/8544b041-b6ab-4b49-bab5-e10237d5c88f.csv"

# %%
r = requests.get(url)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# /usr/local/lib/python3.7/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# /usr/local/lib/python3.7/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# TimeoutError: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x7f9bd9feae50>: Failed to establish a new connection: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# /usr/local/lib/python3.7/dist-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPSConnectionPool(host='odws.hccg.gov.tw', port=443): Max retries exceeded with url: /001/Upload/25/OpenData/9059/59/8544b041-b6ab-4b49-bab5-e10237d5c88f.csv (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f9bd9feae50>: Failed to establish a new connection: [Errno 110] Connection timed out'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-3-4c0e59c26507> in <module>
# ----> 1 r = requests.get(url)
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.7/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='odws.hccg.gov.tw', port=443): Max retries exceeded with url: /001/Upload/25/OpenData/9059/59/8544b041-b6ab-4b49-bab5-e10237d5c88f.csv (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f9bd9feae50>: Failed to establish a new connection: [Errno 110] Connection timed out'))

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# - 對取回來的資料進行編碼

# %%
decoded_content = r.content.decode('utf-8')

# %%
print(decoded_content)
# Out:
# ﻿站點名稱,經度,緯度,圖片URL,站點位置,F6,F7
# 新竹火車站(前站),120.971459,24.801815,http://opendata-manage.hccg.gov.tw/img/24/youbike01.jpg,中華路二段445號(火車站前廣場),,
# 東門圓環,120.970556,24.803866,http://opendata-manage.hccg.gov.tw/img/24/youbike02.jpg,勝利路2號(對面圓環人行道),,
# 新竹市政府,120.96926,24.806138,http://opendata-manage.hccg.gov.tw/img/24/youbike03.jpg,中央路106號(對面人行道),,
# 明志書院立體停車場,120.96576,24.80167,http://opendata-manage.hccg.gov.tw/img/24/youbike04.jpg,西大路317號(停車場前人行道),,
# 辛志平校長故居,120.973662,24.804317,http://opendata-manage.hccg.gov.tw/img/24/youbike05.jpg,東門街32號(汽車停車場),,
# 中正北大路口,120.967098,24.808979,http://opendata-manage.hccg.gov.tw/img/24/youbike06.jpg,中正路146號(機車停車場),,
# 延平停車場,120.956616,24.803791,http://opendata-manage.hccg.gov.tw/img/24/youbike07.jpg,延平路一段159巷22號(對面機車停車格),,
# 建國公園,120.966675,24.803382,http://opendata-manage.hccg.gov.tw/img/24/youbike08.jpg,西門街1號(對面汽車停車格),,
# 新竹公園(公園路),120.978717,24.802579,http://opendata-manage.hccg.gov.tw/img/24/youbike09.jpg,公園路300號(左側人行道),,
# 遠東巨城購物中心,120.974258,24.809326,http://opendata-manage.hccg.gov.tw/img/24/youbike10.jpg,民權路171號(對面人行道),,
# 三民公園,120.979624,24.811226,http://opendata-manage.hccg.gov.tw/img/24/youbike11.jpg,中央路364-1號(網球場前人行道),,
# 新竹轉運站,120.973191,24.800896,http://opendata-manage.hccg.gov.tw/img/24/youbike12.jpg,東南街1巷6號(轉運站對面人行廣場),,
# 新竹馬偕紀念醫院,120.991278,24.800074,http://opendata-manage.hccg.gov.tw/img/24/youbike13.jpg,光復路二段690號(水源街對面公園人行道),,
# 新源建功一路口,120.9932,24.802771,http://opendata-manage.hccg.gov.tw/img/24/youbike14.jpg,新源街138號(對面人行道),,
# 興業二路停車場,120.98996,24.77872,http://opendata-manage.hccg.gov.tw/img/24/youbike63.jpg,興業二路/研新三路口(西側),,

# %% [markdown]
# - 用csv套件解析它

# %%
import csv

# %%
cr = csv.reader(decoded_content.splitlines(), delimiter=',')
data_list = list(cr)

# %% [markdown]
# ## 直接下載檔案解析 (如果使用colab下載csv解析失敗時，使用這邊的程式)
# - 下載的檔案存成bike02.csv，並放在同一資料夾中
# - 下載的檔案連結為[link](https://odws.hccg.gov.tw/001/Upload/25/OpenData/9059/59/8544b041-b6ab-4b49-bab5-e10237d5c88f.csv)

# %%
#使用colab讀csv檔前，需要先使用這行來上傳檔案
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c838f25b-39d6-43dc-95ef-0f851031c6af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c838f25b-39d6-43dc-95ef-0f851031c6af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bike02.csv to bike02.csv

# %%
import csv

fn = 'bike02.csv'
with open(fn, 'r', encoding='big5') as csvfile:
    rows = csv.reader(csvfile)
    data_list = list(rows)

# %% [markdown]
# - 了解 list 的操作

# %%
data_list[0]
# Out:
# ['站點名稱', '經度', '緯度', '圖片URL', '站點位置']

# %%
data_list[1]
# Out:
# ['新竹火車站(站前廣場)',
#  '120.971459',
#  '24.801815',
#  'https://odws.hccg.gov.tw/001/Upload/25/relpic/9059/59/897db4d1-0a4b-4985-a7d4-70545fd3fef5.jpg',
#  '中華路二段445號(火車站前廣場)']

# %%
data_list[1:3]
# Out:
# [['新竹火車站(站前廣場)',
#   '120.971459',
#   '24.801815',
#   'https://odws.hccg.gov.tw/001/Upload/25/relpic/9059/59/897db4d1-0a4b-4985-a7d4-70545fd3fef5.jpg',
#   '中華路二段445號(火車站前廣場)'],
#  ['東門圓環',
#   '120.970556',
#   '24.803866',
#   'https://odws.hccg.gov.tw/001/Upload/25/relpic/9059/59/82c3bb3e-cc01-4a97-ae52-05355baa803d.jpg',
#   '勝利路2號(對面圓環人行道)']]

# %% [markdown]
# - 開炲使用地圖套件標記

# %%
# 可以使用 `pip install folium` 安裝套件
# 使用 `pip install geocoder`

# %%
# 在colab用底下的安裝指令

# !pip install geocoder
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geocoder
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 6.7 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from geocoder) (1.15.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from geocoder) (0.16.0)
# Collecting ratelim
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from geocoder) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from geocoder) (2.23.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ratelim->geocoder) (4.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (2.10)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6

# %%
import folium
import geocoder

# %%
# 使用 geocoder 取得特定住址的 GPS 座標
location = geocoder.osm('新竹市').latlng

# %%
location
# Out:
# [24.8066333, 120.9686833]

# %%
m = folium.Map(location=location, zoom_start=15)

# %%
for item in data_list[1:]:
    try:
        # item[2]=緯度, item[1]=經度, item[0]=名稱
        
        folium.Marker([float(item[2]), float(item[1])],
                      popup=item[0],
                     icon=folium.Icon(color='green', prefix='fa', icon='fa-bicycle')
                     ).add_to(m)
        
    except Exception as e:
        print(e.args)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_692c9492ac8435f417cf62f07ef68dde {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_692c9492ac8435f417cf62f07ef68dde&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_692c9492ac8435f417cf62f07ef68dde = L.map(
#                 &quot;map_692c9492ac8435f417cf62f07ef68dde&quot;,
#                 {
#                     center: [24.8066333, 120.9686833],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_91a447192505398f1e0b6a429fcd60f8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_692c9492ac8435f417cf62f07ef68dde);
#
#
#             var marker_f72e87bdbf57242d5d3ad08d56a26212 = L.marker(
#                 [24.801815, 120.971459],
#                 {}
#             ).addTo(map_692c9492ac8435f417cf62f07ef68dde);
#
#
#             var icon_6df84e1d4181db0a9eb04ad902d3af01 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f72e87bdbf57242d5d3ad08d56a26212.setIcon(icon_6df84e1d4181db0a9eb04ad902d3af01);
#
#
#         var popup_5a20973096ff0f93d786dca9d1e4593b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8eef3d8d6281b50c5b75ac019798c3bb = $(`&lt;div id=&quot;html_8eef3d8d6281b50c5b75ac019798c3bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;新竹火車站(站前廣場)&lt;/div&gt;`)[0];
#             popup_5a20973096ff0f93d786dca9d1e4593b.setContent(html_8eef3d8d6281b50c5b75ac019798c3bb);
#
#
#         marker_f72e87bdbf57242d5d3ad08d56a26212.bindPopup(popup_5a20973096ff0f93d786dca9d1e4593b)
#         ;
#
#
#
#
#             var marker_7d4a27cb7fdc9a620672bb0c516e7128 = L.marker(
#                 [24.803866, 120.970556],
#                 {}
#             ).addTo(map_692c9492ac8435f417cf62f07ef68dde);
#
#
#             var icon_d5d3295849740545095796c5cd6836e5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7d4a27cb7fdc9a620672bb0c516e7128.setIcon(icon_d5d3295849740545095796c5cd6836e5);
#
#
#         var popup_f81ae1ec4a1a1dd321c1ad5af351a630 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_09e3f8edee28efb14c946e5cf79840fd = $(`&lt;div id=&quot;html_09e3f8edee28efb14c946e5cf79840fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;東門圓環&lt;/div&gt;`)[0];
#             popup_f81ae1ec4a1a1dd321c1ad5af351a630.setContent(html_09e3f8edee28efb14c946e5cf79840fd);
#
#
#         marker_7d4a27cb7fdc9a620672bb0c516e7128.bindPopup(popup_f81ae1ec4a1a1dd321c1ad5af351a630)
#         ;
#
#
#
#
#             var marker_248ccfef5b253efdf0c4bbac58d633f2 = L.marker(
#                 [24.806138, 120.96926],
#                 {}
#             ).addTo(map_692c9492ac8435f417cf62f07ef68dde);
#
#
#             var icon_f533fcbb803cb76b7b1c396c7c51800e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_248ccfef5b253efdf0c4bbac58d633f2.setIcon(icon_f533fcbb803cb76b7b1c396c7c51800e);
#
#
#         var popup_e5f24ef13b2a3d56b855931de7ad125a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_fd2ea4ca8040e9b8d57902be5af3ead3 = $(`&lt;div id=&quot;html_fd2ea4ca8040e9b8d57902be5af3ead3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;新竹市政府&lt;/div&gt;`)[0];
#             popup_e5f24ef13b2a3d56b855931de7ad125a.setContent(html_fd2ea4ca8040e9b8d57902be5af3ead3);
#
#
#         marker_248ccfef5b253efdf0c4bbac58d633f2.bindPopup(popup_e5f24ef13b2a3d56b855931de7ad125a)
#         ;
#
#
#
#
#             var marker_d094dd18a59ddf348f9af93d84ed5764 = L.marker(
#                 [24.80167, 120.96576],
#                 {}
#             ).addTo(map_692c9492ac8435f417cf62f07ef68dde);
#
#
#             var icon_8bdd44e5d29c2e65d76d954493be120f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d094dd18a59ddf348f9af93d84ed5764.setIcon(icon_8bdd44e5d29c2e65d76d954493be120f);

# %% [markdown]
# - 下載你的成果

# %%
m.save('demo01.html')

# %% [markdown]
# - 如果使用colab，可以這樣下載成果

# %%
from google.colab import files
files.download('demo01.html')

# %% [markdown]
# - 練習題：改成你所想要的icon
# - icon來源可以參考[這邊](https://fontawesome.com/v4/icons/)

# %%
# TODO: 請在這邊填入你的程式

m = folium.Map(location=location, zoom_start=15)
for item in data_list[1:]:
    try:
        # item[2]=緯度, item[1]=經度, item[0]=名稱
        
        folium.Marker([float(item[2]), float(item[1])],
                      popup=item[0],
                     icon=folium.Icon(color='blue', prefix='fa', icon='fa-car')
                     ).add_to(m)
        
    except Exception as e:
        print(e.args)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3edf50fc69eee3d97bd1af6824eda43 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3edf50fc69eee3d97bd1af6824eda43&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e3edf50fc69eee3d97bd1af6824eda43 = L.map(
#                 &quot;map_e3edf50fc69eee3d97bd1af6824eda43&quot;,
#                 {
#                     center: [24.8066333, 120.9686833],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13c3a55e374bde3ea4b4604b946cca3a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e3edf50fc69eee3d97bd1af6824eda43);
#
#
#             var marker_39f66543cf2903c75af8353044a18b2a = L.marker(
#                 [24.801815, 120.971459],
#                 {}
#             ).addTo(map_e3edf50fc69eee3d97bd1af6824eda43);
#
#
#             var icon_181c215432b40ac4ae5eb7f1fb3c10f6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-car&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_39f66543cf2903c75af8353044a18b2a.setIcon(icon_181c215432b40ac4ae5eb7f1fb3c10f6);
#
#
#         var popup_26403e61470f2494b5257cd05b6d1524 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5246b7834c2df86fbc720fd0d0c19de2 = $(`&lt;div id=&quot;html_5246b7834c2df86fbc720fd0d0c19de2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;新竹火車站(站前廣場)&lt;/div&gt;`)[0];
#             popup_26403e61470f2494b5257cd05b6d1524.setContent(html_5246b7834c2df86fbc720fd0d0c19de2);
#
#
#         marker_39f66543cf2903c75af8353044a18b2a.bindPopup(popup_26403e61470f2494b5257cd05b6d1524)
#         ;
#
#
#
#
#             var marker_e339c9e4e1713e19103316d1dc40e191 = L.marker(
#                 [24.803866, 120.970556],
#                 {}
#             ).addTo(map_e3edf50fc69eee3d97bd1af6824eda43);
#
#
#             var icon_67063e4dd2441da7c8b423c9d0dd4896 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-car&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e339c9e4e1713e19103316d1dc40e191.setIcon(icon_67063e4dd2441da7c8b423c9d0dd4896);
#
#
#         var popup_cc49ebd732a0e07237ef84396ec96692 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7749fb273d817f555bae3908dccab2cb = $(`&lt;div id=&quot;html_7749fb273d817f555bae3908dccab2cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;東門圓環&lt;/div&gt;`)[0];
#             popup_cc49ebd732a0e07237ef84396ec96692.setContent(html_7749fb273d817f555bae3908dccab2cb);
#
#
#         marker_e339c9e4e1713e19103316d1dc40e191.bindPopup(popup_cc49ebd732a0e07237ef84396ec96692)
#         ;
#
#
#
#
#             var marker_0cbfa83a6d11040e448dd6b6448b08a5 = L.marker(
#                 [24.806138, 120.96926],
#                 {}
#             ).addTo(map_e3edf50fc69eee3d97bd1af6824eda43);
#
#
#             var icon_4a3f6e19f65b1573771c73d83373773e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-car&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0cbfa83a6d11040e448dd6b6448b08a5.setIcon(icon_4a3f6e19f65b1573771c73d83373773e);
#
#
#         var popup_650b32b44fba737abe4fe1134e0461a7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e393aa05c8bb052f8cfe9162151b619f = $(`&lt;div id=&quot;html_e393aa05c8bb052f8cfe9162151b619f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;新竹市政府&lt;/div&gt;`)[0];
#             popup_650b32b44fba737abe4fe1134e0461a7.setContent(html_e393aa05c8bb052f8cfe9162151b619f);
#
#
#         marker_0cbfa83a6d11040e448dd6b6448b08a5.bindPopup(popup_650b32b44fba737abe4fe1134e0461a7)
#         ;
#
#
#
#
#             var marker_f30552dcf35e8ef5abb190b18324b42f = L.marker(
#                 [24.80167, 120.96576],
#                 {}
#             ).addTo(map_e3edf50fc69eee3d97bd1af6824eda43);
#
#
#             var icon_b0c0a9a3bcf822f72174af27a09fb4cb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-car&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f30552dcf35e8ef5abb190b18324b42f.setIcon(icon_b0c0a9a3bcf822f72174af27a09fb4cb);
#
#
#         var popup_2255c

# %% [markdown]
# - 練習題: 試著使用tooltip取代popup參數

# %%
# TODO: 請在這邊填入你的程式

m = folium.Map(location=location, zoom_start=15)
for item in data_list[1:]:
    try:
        # item[2]=緯度, item[1]=經度, item[0]=名稱
        
        folium.Marker([float(item[2]), float(item[1])],
                      tooltip=item[0],
                     icon=folium.Icon(color='blue', prefix='fa', icon='fa-car')
                     ).add_to(m)
        
    except Exception as e:
        print(e.args)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_22f052c97a6df4a24f182f700e81a6ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_22f052c97a6df4a24f182f700e81a6ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_22f052c97a6df4a24f182f700e81a6ea = L.map(
#                 &quot;map_22f052c97a6df4a24f182f700e81a6ea&quot;,
#                 {
#                     center: [24.8066333, 120.9686833],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f051fb1068bff14ee6e647927f500e8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_22f052c97a6df4a24f182f700e81a6ea);
#
#
#             var marker_71012b59c18b12e234236f4c388fa060 = L.marker(
#                 [24.801815, 120.971459],
#                 {}
#             ).addTo(map_22f052c97a6df4a24f182f700e81a6ea);
#
#
#             var icon_56d0f575d0fa369057d4f7ff035fb871 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-car&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_71012b59c18b12e234236f4c388fa060.setIcon(icon_56d0f575d0fa369057d4f7ff035fb871);
#
#
#             marker_71012b59c18b12e234236f4c388fa060.bindTooltip(
#                 `&lt;div&gt;
#                      新竹火車站(站前廣場)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_82bbc0651dc811fa55044dfb88cf893f = L.marker(
#                 [24.803866, 120.970556],
#                 {}
#             ).addTo(map_22f052c97a6df4a24f182f700e81a6ea);
#
#
#             var icon_80b59cef36b5f810ef9fe66dc3b3a35d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-car&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_82bbc0651dc811fa55044dfb88cf893f.setIcon(icon_80b59cef36b5f810ef9fe66dc3b3a35d);
#
#
#             marker_82bbc0651dc811fa55044dfb88cf893f.bindTooltip(
#                 `&lt;div&gt;
#                      東門圓環
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7daae5560820982af23fe51f57042498 = L.marker(
#                 [24.806138, 120.96926],
#                 {}
#             ).addTo(map_22f052c97a6df4a24f182f700e81a6ea);
#
#
#             var icon_5a68bb6b59884505c1c1fe4a098a19d7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-car&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7daae5560820982af23fe51f57042498.setIcon(icon_5a68bb6b59884505c1c1fe4a098a19d7);
#
#
#             marker_7daae5560820982af23fe51f57042498.bindTooltip(
#                 `&lt;div&gt;
#                      新竹市政府
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bd7f4a6f7e2780c9ef0ea83706ade371 = L.marker(
#                 [24.80167, 120.96576],
#                 {}
#             ).addTo(map_22f052c97a6df4a24f182f700e81a6ea);
#
#
#             var icon_e789cbadecd555fda011fa0d1a614530 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-car&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_bd7f4a6f7e2780c9ef0ea83706ade371.setIcon(icon_e789cbadecd555fda011fa0d1a614530);
#
#
#             marker_bd7f4a6f7e2780c9ef0ea83706ade371.bindTooltip(
#                 `&lt;div&gt;
#                      明志書院立體停車場
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4dbd2310b5dddd629607bde0d0034ceb = L.marker(
#                 [24.804317, 120.973662],
#                 {}
#             ).addTo(map_22f052c97a6df4a24f182f700e81a6ea);
#
#
#             var icon_3496db1228a9fc09bc9fc4e4713fe0d1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-car&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_4dbd2310b5dddd629607bde0d0034ceb.setIcon(icon_3496db1228a9fc09bc9fc4e4713fe0d1);
#
#
#             marker_4dbd2310b5dddd629607bde0d0034ceb.bindTooltip(
#                 `&lt;div&gt;
#                      辛志平校長故居
